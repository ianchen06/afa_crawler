# %%
import pandas as pd

# %%
df = pd.read_csv('afa.csv',header=None, names=['idx', '市場',
 '產品',
 '上價',
 '中價',
 '下價',
 '平均價(元/公斤)',
 '跟前一交易日比較%',
 '交易量(公斤)',
 '跟前一交易日比較%', 'dt'])

# %%
df.head()
# Out:
#    idx       市場               產品    上價    中價    下價  平均價(元/公斤) 跟前一交易日比較%  \
# 0    2  104 台北二          FA1 黃秋葵  89.3  39.3  17.3       44.9       + 0
# 1    3  104 台北二  FB11 花椰菜 青梗 留梗柄  32.6  25.2  16.4       24.9      - 16
# 2    4  104 台北二        FC1 胡瓜 黑刺  33.4  23.7  18.7       24.7      + 12
# 3    5  104 台北二          FD1 花胡瓜  46.9  37.2  26.6       37.0       - 8
# 4    6  104 台北二        FE1 冬瓜 白皮   6.0   5.2   4.0        5.1      + 11
#
#    交易量(公斤) 跟前一交易日比較%.1                         dt
# 0      741         - 0  2017-11-26T00:00:00+08:00
# 1    20242        + 43  2017-11-26T00:00:00+08:00
# 2     4191        - 23  2017-11-26T00:00:00+08:00
# 3     7812        + 15  2017-11-26T00:00:00+08:00
# 4     1417        - 44  2017-11-26T00:00:00+08:00

# %%
df.groupby('產品').mean()
# Out:
#                          idx          上價          中價          下價   平均價(元/公斤)  \
# 產品
# FA0 其他花類          265.630687   83.677877   75.165299   68.809634   75.598216
# FA1 黃秋葵           825.271625   70.751750   47.553281   27.210469   48.015440
# FA2 樊花            322.600592   18.965976   17.843787   16.694083   17.902959
# FA4 瓊花            569.642857    8.250000    7.896429    7.321429    7.860714
# FA9 百果 進口         155.476703  241.397849  236.036201  233.763441  236.653763
# FB0 花椰菜 其他        406.542373   38.408866   31.730117   27.530117   32.193351
# FB1 花椰菜 青梗        946.204933   45.233782   33.769582   23.145169   33.458526
# FB11 花椰菜 青梗 留梗柄   437.683728   68.755000   47.165680   27.254083   47.501036
# FB2 花椰菜 白梗       1254.925278   41.540863   28.977711   19.526003   29.355679
# FB21 花椰菜 白梗 留梗柄   408.064516   22.327419   22.253226   22.045161   22.224194
# FB9 花椰菜 進口        322.837158   66.532787   61.587650   55.922295   61.455519
# ...
